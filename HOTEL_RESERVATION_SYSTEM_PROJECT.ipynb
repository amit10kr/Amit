# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Importing Hotel Reservation Dataset

# %%
df = pd.read_csv("hotel reservation system.csv")
df
# Out:
#        Adults  Children  Weekend_Nights  week_Nights Type_Of_Meals  \
# 0           2         0               1            2           Veg
# 1           2         0               2            3          None
# 2           1         0               2            1           Veg
# 3           2         0               0            2           Veg
# 4           2         0               1            1          None
# ...       ...       ...             ...          ...           ...
# 20675       2         0               0            2          None
# 20676       2         0               0            3           Veg
# 20677       1         0               0            3           Veg
# 20678       3         0               1            4           Veg
# 20679       2         0               1            2           Veg
#
#       Type_Of_Room  Year Month  Date Repeated_Guest  Avg_price_Per_Room  \
# 0       Single Bed  2017   Oct     2             No               65.00
# ...

# %%
df.shape  # Tell's No. Of Rows And Columns
# Out:
# (20680, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20680 entries, 0 to 20679
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Adults                  20680 non-null  int64
#  1   Children                20680 non-null  int64
#  2   Weekend_Nights          20680 non-null  int64
#  3   week_Nights             20680 non-null  int64
#  4   Type_Of_Meals           20680 non-null  object
#  5   Type_Of_Room            20680 non-null  object
#  6   Year                    20680 non-null  int64
#  7   Month                   20680 non-null  object
#  8   Date                    20680 non-null  int64
#  9   Repeated_Guest          20680 non-null  object
#  10  Avg_price_Per_Room      20680 non-null  float64
#  11  No_Of_Special_Requests  20680 non-null  int64
#  12  booking_status          20680 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#              Adults      Children  Weekend_Nights   week_Nights          Year  \
# count  20680.000000  20680.000000    20680.000000  20680.000000  20680.000000
# mean       1.849855      0.103868        0.814217      2.205609   2017.822824
# std        0.515104      0.403985        0.874554      1.421304      0.381827
# min        0.000000      0.000000        0.000000      0.000000   2017.000000
# 25%        2.000000      0.000000        0.000000      1.000000   2018.000000
# 50%        2.000000      0.000000        1.000000      2.000000   2018.000000
# 75%        2.000000      0.000000        2.000000      3.000000   2018.000000
# max        4.000000     10.000000        7.000000     17.000000   2018.000000
#
#                Date  Avg_price_Per_Room  No_Of_Special_Requests
# count  20680.000000        20680.000000            20680.000000
# mean      15.530996          103.508308                0.626983
# std        8.718669           34.853277                0.787510
# ...

# %%
df.count()  # Tell's No Of Filled Elements
# Out:
# Adults                    20680
# Children                  20680
# Weekend_Nights            20680
# week_Nights               20680
# Type_Of_Meals             20680
# Type_Of_Room              20680
# Year                      20680
# Month                     20680
# Date                      20680
# Repeated_Guest            20680
# Avg_price_Per_Room        20680
# No_Of_Special_Requests    20680
# booking_status            20680
# dtype: int64

# %%
df.head() # Will Display First 5 rows
# Out:
#    Adults  Children  Weekend_Nights  week_Nights Type_Of_Meals Type_Of_Room  \
# 0       2         0               1            2           Veg   Single Bed
# 1       2         0               2            3          None   Single Bed
# 2       1         0               2            1           Veg   Single Bed
# 3       2         0               0            2           Veg   Single Bed
# 4       2         0               1            1          None   Single Bed
#
#    Year Month  Date Repeated_Guest  Avg_price_Per_Room  \
# 0  2017   Oct     2             No               65.00
# 1  2018   Nov     6             No              106.68
# 2  2018   Feb    28             No               60.00
# 3  2018   May    20             No              100.00
# 4  2018   Apr    11             No               94.50
#
#    No_Of_Special_Requests booking_status
# 0                       0      Confirmed
# 1                       1      Confirmed
# 2                       0       Canceled
# ...

# %%
df.tail() # Will Display Last 5 Rows
# Out:
#        Adults  Children  Weekend_Nights  week_Nights Type_Of_Meals  \
# 20675       2         0               0            2          None
# 20676       2         0               0            3           Veg
# 20677       1         0               0            3           Veg
# 20678       3         0               1            4           Veg
# 20679       2         0               1            2           Veg
#
#       Type_Of_Room  Year Month  Date Repeated_Guest  Avg_price_Per_Room  \
# 20675   Single Bed  2018   Oct     7             No              135.00
# 20676   Single Bed  2018   Aug    30             No               80.32
# 20677   Single Bed  2018   Aug    11             No               90.90
# 20678    Queen Bed  2018   Aug     8             No              130.05
# 20679   Single Bed  2018   Jan    18             No               87.00
#
#        No_Of_Special_Requests booking_status
# 20675                       1      Confirmed
# ...

# %% [markdown]
# ### Finding Out Whether Null Value Is There Or Not

# %%
df.isnull().sum() # There Is No Null Value In Dataset
# Out:
# Adults                    0
# Children                  0
# Weekend_Nights            0
# week_Nights               0
# Type_Of_Meals             0
# Type_Of_Room              0
# Year                      0
# Month                     0
# Date                      0
# Repeated_Guest            0
# Avg_price_Per_Room        0
# No_Of_Special_Requests    0
# booking_status            0
# dtype: int64

# %% [markdown]
# ## Print 'Date' column in decending order

# %%
df.sort_values(by='Date',ascending = False)   # print in decending
# Out:
#        Adults  Children  Weekend_Nights  week_Nights Type_Of_Meals  \
# 3346        2         0               0            4          None
# 19947       1         0               0            2           Veg
# 5845        2         1               0            3           Veg
# 16512       2         0               1            0           Veg
# 14117       2         0               0            3           Veg
# ...       ...       ...             ...          ...           ...
# 14305       2         0               0            2           Veg
# 14301       3         0               0            2           Veg
# 18004       2         0               0            4           Veg
# 10698       2         0               1            2           Veg
# 4478        2         0               1            3          None
#
#       Type_Of_Room  Year Month  Date Repeated_Guest  Avg_price_Per_Room  \
# 3346    Single Bed  2018   Aug    31             No              120.60
# ...

# %% [markdown]
# # Plots

# %%
df['booking_status'].value_counts().plot(kind='bar')  # Bar Plot
# Out:
# <Axes: >

# %%
corr = df.corr()
plt.figure(figsize=(15, 8))
sns.heatmap(corr, vmin=-1, vmax=1, center=0, annot=True)  # HeatMap
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_13400\2639648785.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >

# %%
sns.pairplot(df)

# %%
df['booking_status'].value_counts().plot(kind='pie')
explode=(0.1,0)  # Pie Plot

# %% [markdown]
# ### Changing Canceled to 0 & Confirmed to 1

# %%
df['booking_status']=df['booking_status'].map({'Canceled':0,'Confirmed':1})
df
# Out:
#        Adults  Children  Weekend_Nights  week_Nights Type_Of_Meals  \
# 0           2         0               1            2           Veg
# 1           2         0               2            3          None
# 2           1         0               2            1           Veg
# 3           2         0               0            2           Veg
# 4           2         0               1            1          None
# ...       ...       ...             ...          ...           ...
# 20675       2         0               0            2          None
# 20676       2         0               0            3           Veg
# 20677       1         0               0            3           Veg
# 20678       3         0               1            4           Veg
# 20679       2         0               1            2           Veg
#
#       Type_Of_Room  Year Month  Date Repeated_Guest  Avg_price_Per_Room  \
# 0       Single Bed  2017   Oct     2             No               65.00
# ...

# %%
df.columns
# Out:
# Index(['Adults', 'Children', 'Weekend_Nights', 'week_Nights', 'Type_Of_Meals',
#        'Type_Of_Room', 'Year', 'Month', 'Date', 'Repeated_Guest',
#        'Avg_price_Per_Room', 'No_Of_Special_Requests', 'booking_status'],
#       dtype='object')

# %% [markdown]
# ## Splitting Data In 'x' & 'y'

# %%
x = df[[ 'Adults', 'Children', 'Weekend_Nights','week_Nights','Date','Avg_price_Per_Room','No_Of_Special_Requests']]
y = df['booking_status']

# %%
x
# Out:
#        Adults  Children  Weekend_Nights  week_Nights  Date  \
# 0           2         0               1            2     2
# 1           2         0               2            3     6
# 2           1         0               2            1    28
# 3           2         0               0            2    20
# 4           2         0               1            1    11
# ...       ...       ...             ...          ...   ...
# 20675       2         0               0            2     7
# 20676       2         0               0            3    30
# 20677       1         0               0            3    11
# 20678       3         0               1            4     8
# 20679       2         0               1            2    18
#
#        Avg_price_Per_Room  No_Of_Special_Requests
# 0                   65.00                       0
# 1                  106.68                       1
# 2                   60.00                       0
# 3                  100.00                       0
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 20675    1
# 20676    1
# 20677    0
# 20678    0
# 20679    1
# Name: booking_status, Length: 20680, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.001, random_state= 62)

# %%
x_train
# Out:
#        Adults  Children  Weekend_Nights  week_Nights  Date  \
# 16724       3         0               0            4     7
# 8402        2         2               0            1     1
# 1539        2         0               1            5    27
# 7207        2         0               0            3    24
# 5663        2         0               2            5    15
# ...       ...       ...             ...          ...   ...
# 2163        2         0               2            2     9
# 8073        1         0               0            2    17
# 9809        2         0               0            3    30
# 15384       2         0               1            3     3
# 9746        2         0               0            2     4
#
#        Avg_price_Per_Room  No_Of_Special_Requests
# 16724              158.85                       0
# 8402               174.00                       0
# 1539               116.73                       2
# 7207               165.00                       1
# ...

# %%
y_train
# Out:
# 16724    0
# 8402     1
# 1539     1
# 7207     1
# 5663     1
#         ..
# 2163     0
# 8073     1
# 9809     0
# 15384    1
# 9746     0
# Name: booking_status, Length: 20659, dtype: int64

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
#from sklearn.datasets import make_classification
rf =  RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = rf.predict(x_test)

# %% [markdown]
# ## Result

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
cm = confusion_matrix(y_test,pred)  # Classification Report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92         6
#            1       1.00      0.93      0.97        15
#
#     accuracy                           0.95        21
#    macro avg       0.93      0.97      0.94        21
# weighted avg       0.96      0.95      0.95        21

# %%
sns.heatmap(cm, annot = True, fmt = 'g', cbar = False, cmap = 'icefire', linewidths= 0.5, linecolor= 'grey')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')  # HeatMap
# Out:
# Text(0.5, 23.52222222222222, 'Predicted Values')

# %%
# Accuracy Score
rf.score(x_test,y_test)
# Out:
# 0.9523809523809523

# %% [markdown]
# # Accuracy Comes Out To Be 95% (Approx)

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
